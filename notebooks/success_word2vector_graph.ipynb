# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import urllib

# %%
import zipfile
#%matplotlib inline
from matplotlib import pylab
#font_cache_path = mpl.get_cachedir() + '/fontList.cache'
#%rm $font_cache_path

from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print 'Found and verified', filename
  else:
    print statinfo.st_size
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return f.read(name).split()
  f.close()
  
words = read_data(filename)
print 'Data size', len(words)
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print 'Most common words (+UNK)', count[:5]
print 'Sample data', data[:10]
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size / num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print batch[i], '->', labels[i, 0]
  print reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]]
# Out:
# 3084 -> 5239
# originated -> anarchism
# 3084 -> 12
# originated -> as
# 12 -> 3084
# as -> originated
# 12 -> 6
# as -> a
# 6 -> 12
# a -> as
# 6 -> 195
# a -> term
# 195 -> 6
# term -> a
# 195 -> 2
# term -> of

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(xrange(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  average_loss = 0
  for step in xrange(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print "Average loss at step", step, ":", average_loss
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = "%s %s," % (log, close_word)
        print log
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0 : 8.34104537964
# Nearest to can: hampering, france, tudor, habit, jordanes, suzaku, lillehammer, roadway,
# Nearest to of: exists, decimals, pigeon, destroys, adaptor, aztec, leviathan, thin,
# Nearest to had: duval, arboreal, reverberation, southend, percival, mbta, carolyn, paralipomena,
# Nearest to some: croce, azt, bugs, emb, financial, evenings, vernacular, watchmen,
# Nearest to to: serialised, cil, awakened, maverick, packaging, oddities, beeswax, consists,
# Nearest to than: biblical, uncompressed, cajun, ghola, castrated, mechanised, hypatia, kx,
# Nearest to they: franciscan, virtuoso, rancher, gallardo, technician, kool, forgetting, jakobson,
# Nearest to over: dreadnoughts, complying, delegations, gassing, kelvin, siberia, mascarene, give,
# Nearest to in: dipping, sao, gloucestershire, pick, gretzky, restraining, whitfield, preaching,
# Nearest to not: organization, debatable, aris, laing, insight, stony, auteur, zilog,
# Nearest to most: lac, toussaint, confucian, een, lucky, vestalia, hypothetically, intuitionist,
# Nearest to these: weathered, balliol, prisms, wallet, redesigned, rig, cymru, murr,
# Nearest to by: vicente, reprisal, jodie, providing, thumbs, iie, incunabula, websites,
# Nearest to state: moss, harshness, spink, fontana, judaizers, gazette, princess, depart,
# Nearest to new: buena, satirist, december, straddles, ilyich, uphill, hauled, cuneiform,
# Nearest to for: pares, layman, oxidase, yes, liu, stated, hebrew, glossary,
# Average loss at step 2000 : 4.36328048265
# Average loss at step 4000 : 3.86440442872
# Average loss at step 6000 : 3.78624243069
# Average loss at step 8000 : 3.68903553146
# Average loss at step 10000 : 3.60907210243
# Nearest to can: would, may, will, modernised, could, abandons, aesthetically, harvest,
# Nearest to of: in, second, for, during, pis, aztec, bandleader, bowled,
# Nearest to had: has, was, have, kellermann, would, managed, meherabad, cma,
# Nearest to some: many, bugs, strunk, azt, cheshire, emb, secretary, quadrant,
# Nearest to to: not, cil, awakened, materialism, noncommercial, slapped, would, rarity,
# Nearest to than: buson, tobit, stump, league, biblical, simultaneously, bulky, exploring,
# Nearest to they: he, we, there, not, it, hazard, dissociative, never,
# Nearest to over: complying, dreadnoughts, ulema, kelvin, mathematical, including, button, turkestan,
# Nearest to in: of, on, at, from, during, with, cytosine, uart,
# Nearest to not: it, they, to, oligopoly, partner, debatable, also, richter,
# Nearest to most: many, vestalia, modernisation, lucky, intuitionist, other, forest, ero,
# Nearest to these: which, capsule, conspirator, restricts, spiced, some, all, berger,
# Nearest to by: with, jed, be, was, thumbs, vigil, truer, in,
# Nearest to state: depart, robinson, degeneracy, moss, perceive, pantheon, harshness, logician,
# Nearest to new: buena, issachar, broccoli, blinds, vought, checked, longbows, suse,
# Nearest to for: with, of, in, fox, negative, centaurs, vaughn, tiananmen,
# Average loss at step 12000 : 3.60567132503
# Average loss at step 14000 : 3.56878059173
# Average loss at step 16000 : 3.40366603601
# Average loss at step 18000 : 3.45916794109
# Average loss at step 20000 : 3.53681074476
# Nearest to can: may, would, will, could, should, cannot, must, might,
# Nearest to of: for, meriwether, bess, broadcasters, in, apostle, sedimentary, quinlan,
# Nearest to had: has, have, were, kellermann, was, meherabad, unverified, would,
# Nearest to some: many, these, their, all, most, its, cheshire, other,
# Nearest to to: would, not, awakened, may, can, will, maverick, cil,
# Nearest to than: or, ilyich, buson, stump, realizes, much, direction, moat,
# Nearest to they: he, there, we, she, it, you, who, not,
# Nearest to over: complying, including, connecting, forbidding, into, erik, pausanias, dreadnoughts,
# Nearest to in: at, during, from, on, uart, indeed, contour, under,
# Nearest to not: they, also, to, partner, widely, we, it, debatable,
# Nearest to most: many, modernisation, more, some, vestalia, breakaway, forest, lucky,
# Nearest to these: all, some, which, many, elaborately, the, restricts, merseyside,
# Nearest to by: be, eternally, were, with, for, was, boomers, in,
# Nearest to state: pantheon, robinson, fluorite, degeneracy, moss, magnetic, depart, princess,
# Nearest to new: longbows, buena, broccoli, oud, vought, issachar, meredith, blinds,
# Nearest to for: of, vaughn, on, barak, manatees, by, in, with,
# Average loss at step 22000 : 3.50145583618
# Average loss at step 24000 : 3.4895990572
# Average loss at step 26000 : 3.47778366292
# Average loss at step 28000 : 3.47935806423
# Average loss at step 30000 : 3.49947181967
# Nearest to can: would, may, will, could, should, must, cannot, might,
# Nearest to of: in, entire, from, wittelsbach, bowled, ample, tags, bess,
# Nearest to had: has, have, was, were, kellermann, unverified, is, been,
# Nearest to some: many, these, several, most, all, other, their, various,
# Nearest to to: would, awakened, will, maverick, spinning, can, not, could,
# Nearest to than: buson, ilyich, direction, stump, realizes, prevented, much, barra,
# Nearest to they: he, there, we, it, she, you, who, not,
# Nearest to over: latest, into, including, turkestan, complying, pausanias, sforza, connecting,
# Nearest to in: at, on, from, between, during, with, of, within,
# Nearest to not: they, it, never, to, also, wroc, wahid, we,
# Nearest to most: more, many, some, modernisation, lucky, use, lettres, cory,
# Nearest to these: some, all, many, which, they, such, their, elaborately,
# Nearest to by: in, eternally, was, galactus, longue, under, dacian, were,
# Nearest to state: fluorite, classifies, moss, degeneracy, useful, slips, spotters, pantheon,
# Nearest to new: broccoli, longbows, pleistocene, vought, ame, buena, issachar, delegate,
# Nearest to for: amenable, loyal, with, on, when, vaughn, oscillation, antithetical,
# Average loss at step 32000 : 3.50456581116
# Average loss at step 34000 : 3.4876016981
# Average loss at step 36000 : 3.45510548568
# Average loss at step 38000 : 3.29838236296
# Average loss at step 40000 : 3.4260440616
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to of: in, bowled, for, including, mediocre, final, involving, same,
# Nearest to had: has, have, was, were, kellermann, unverified, would, truso,
# Nearest to some: many, these, several, any, various, their, most, certain,
# Nearest to to: awakened, can, would, should, will, maverick, could, emphasise,
# Nearest to than: or, buson, much, ilyich, barns, treasured, prevented, pmid,
# Nearest to they: we, he, there, you, it, she, these, however,
# Nearest to over: into, corroborated, sforza, turkestan, sarcastic, forbidding, veer, latest,
# Nearest to in: during, of, within, and, binary, on, from, at,
# Nearest to not: they, usually, never, it, wahid, herring, often, also,
# Nearest to most: more, many, modernisation, some, lucky, setups, aa, expound,
# Nearest to these: some, many, such, all, which, both, several, they,
# Nearest to by: jed, with, as, carcinogenic, heresy, ogg, was, be,
# Nearest to state: degeneracy, spotters, slips, pantheon, classifies, gazette, withdrew, fluorite,
# Nearest to new: commitment, delegate, sympathizers, single, issachar, authoring, impressions, broccoli,
# Nearest to for: amenable, while, of, vaughn, skyscraper, with, oily, in,
# Average loss at step 42000 : 3.43195932829
# Average loss at step 44000 : 3.45179271841
# Average loss at step 46000 : 3.44468718714
# Average loss at step 48000 : 3.35302321649
# Average loss at step 50000 : 3.38381131887
# Nearest to can: could, will, would, may, must, should, cannot, might,
# Nearest to of: including, in, irrigated, and, honesty, same, spraying, salome,
# Nearest to had: has, have, were, was, kellermann, having, managed, never,
# Nearest to some: many, these, several, various, those, most, both, all,
# Nearest to to: would, awakened, should, could, ruddy, can, cil, will,
# Nearest to than: or, much, ilyich, while, direction, democratisation, skim, barns,
# Nearest to they: there, he, we, she, you, it, these, soon,
# Nearest to over: turkestan, into, latest, sforza, distracting, pausanias, corroborated, across,
# Nearest to in: on, during, from, within, at, near, of, between,
# Nearest to not: now, usually, still, never, they, typically, fairly, ripening,
# Nearest to most: more, some, many, modernisation, aa, less, use, detested,
# Nearest to these: some, many, both, such, those, several, elaborately, all,
# Nearest to by: through, jed, under, was, receives, in, be, including,
# Nearest to state: degeneracy, harvard, gazette, regrets, fluorite, withdrew, spink, spotters,
# Nearest to new: salamander, single, sympathizers, mabuse, blinds, drunkenness, sublime, geckos,
# Nearest to for: while, official, tiananmen, barak, manatees, adages, negative, against,
# Average loss at step 52000 : 3.43446226609
# Average loss at step 54000 : 3.43013669252
# Average loss at step 56000 : 3.43734391069
# Average loss at step 58000 : 3.39487118357
# Average loss at step 60000 : 3.39546443763
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to of: for, in, same, including, vast, elbridge, bess, outer,
# Nearest to had: has, have, was, were, kellermann, having, been, bianchi,
# Nearest to some: many, several, these, most, various, any, this, both,
# Nearest to to: awakened, encircle, vasili, kidnap, for, emphasise, otherwise, not,
# Nearest to than: much, or, but, ilyich, direction, proved, rature, crying,
# Nearest to they: we, there, he, you, she, these, it, not,
# Nearest to over: into, turkestan, sforza, corroborated, latest, through, across, sarcastic,
# Nearest to in: within, during, among, harriman, of, between, throughout, at,
# Nearest to not: usually, still, never, it, herring, now, they, wahid,
# Nearest to most: many, more, some, modernisation, detested, use, aa, less,
# Nearest to these: some, many, those, both, they, elaborately, several, such,
# Nearest to by: through, vigil, was, with, emanating, jed, be, eternally,
# Nearest to state: degeneracy, slips, regrets, harvard, government, brand, spotters, pantheon,
# Nearest to new: salamander, issachar, nicola, single, pleistocene, geckos, mabuse, clifton,
# Nearest to for: of, including, vaughn, while, when, forbid, barak, although,
# Average loss at step 62000 : 3.24108378214
# Average loss at step 64000 : 3.25278674507
# Average loss at step 66000 : 3.40424745917
# Average loss at step 68000 : 3.39133260775
# Average loss at step 70000 : 3.35683538353
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to of: including, include, shilton, bowled, original, in, for, destroys,
# Nearest to had: have, has, was, were, kellermann, having, perutz, recently,
# Nearest to some: many, several, these, various, both, all, most, the,
# Nearest to to: will, emphasise, would, can, awakened, reviewed, must, could,
# Nearest to than: while, or, much, skim, but, barra, ilyich, crying,
# Nearest to they: we, he, there, she, you, it, these, pushed,
# Nearest to over: latest, distracting, sarcastic, turkestan, sforza, athletes, across, ulema,
# Nearest to in: within, during, on, for, throughout, using, from, through,
# Nearest to not: never, still, usually, now, herring, almost, typically, generally,
# Nearest to most: more, many, some, less, modernisation, detested, use, drachmae,
# Nearest to these: some, many, such, those, several, they, elaborately, certain,
# Nearest to by: jed, through, eternally, slid, banco, be, was, defoe,
# Nearest to state: degeneracy, city, states, government, slips, harvard, logitech, brand,
# Nearest to new: nicola, single, salamander, particular, pleistocene, clifton, noble, ranger,
# Nearest to for: while, in, without, barak, if, amenable, of, alsos,
# Average loss at step 72000 : 3.37629517531
# Average loss at step 74000 : 3.34359503165
# Average loss at step 76000 : 3.31263670617
# Average loss at step 78000 : 3.34496859813
# Average loss at step 80000 : 3.37592411077
# Nearest to can: could, may, will, would, must, cannot, should, might,
# Nearest to of: including, in, original, entire, vast, gigi, despite, bess,
# Nearest to had: has, have, was, were, having, began, kellermann, been,
# Nearest to some: many, several, various, these, both, most, all, those,
# Nearest to to: would, will, can, encircle, cannot, could, should, ivanovich,
# Nearest to than: while, much, and, or, but, ilyich, skim, rature,
# Nearest to they: we, he, there, she, you, it, these, segments,
# Nearest to over: into, across, turkestan, corroborated, sarcastic, latest, through, bernie,
# Nearest to in: within, during, on, until, since, under, throughout, of,
# Nearest to not: still, never, typically, often, actually, always, now, intends,
# Nearest to most: many, more, some, modernisation, less, detested, setups, lettres,
# Nearest to these: several, those, many, some, such, both, elaborately, various,
# Nearest to by: defoe, through, connotes, jackson, emanating, was, banco, when,
# Nearest to state: city, states, degeneracy, brand, circle, government, suarez, classifies,
# Nearest to new: single, salamander, sympathizers, nicola, beating, particular, clifton, different,
# Nearest to for: while, amenable, blica, ferenc, when, without, goo, sheave,
# Average loss at step 82000 : 3.40905881447
# Average loss at step 84000 : 3.40481942844
# Average loss at step 86000 : 3.39161195898
# Average loss at step 88000 : 3.35527492934
# Average loss at step 90000 : 3.36424319375
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to of: including, in, for, include, bowled, outer, ici, previous,
# Nearest to had: has, have, was, were, having, kellermann, managed, druid,
# Nearest to some: many, several, these, both, those, various, any, most,
# Nearest to to: will, would, ivanovich, towards, awakened, kidnap, should, pedagogue,
# Nearest to than: much, characterizes, far, while, ilyich, but, skim, becomes,
# Nearest to they: we, he, she, there, you, it, these, segments,
# Nearest to over: across, corroborated, turkestan, into, cheka, bernie, against, bruin,
# Nearest to in: within, during, on, of, near, until, from, under,
# Nearest to not: still, never, now, always, therefore, herring, generally, actually,
# Nearest to most: many, more, modernisation, some, less, several, jacquard, cory,
# Nearest to these: several, some, many, those, certain, such, are, instead,
# Nearest to by: through, under, with, when, without, defoe, emanating, eternally,
# Nearest to state: city, degeneracy, spotters, regrets, states, government, impedance, slips,
# Nearest to new: particular, sympathizers, clifton, different, modern, intervention, oud, beating,
# Nearest to for: while, including, without, of, blica, when, sheave, oily,
# Average loss at step 92000 : 3.39517710769
# Average loss at step 94000 : 3.25594853455
# Average loss at step 96000 : 3.35625702631
# Average loss at step 98000 : 3.24228255108
# Average loss at step 100000 : 3.35693676955
# Nearest to can: could, may, must, will, would, should, cannot, might,
# Nearest to of: bowled, original, smugglers, including, physicalism, entire, destroys, salome,
# Nearest to had: has, have, was, kellermann, would, having, were, perutz,
# Nearest to some: many, several, these, any, various, certain, all, those,
# Nearest to to: will, could, can, would, must, cannot, should, may,
# Nearest to than: or, and, while, much, crying, ilyich, ridges, barra,
# Nearest to they: we, there, he, she, you, it, i, these,
# Nearest to over: across, corroborated, turkestan, cheka, latest, through, into, bruin,
# Nearest to in: during, within, throughout, until, from, on, at, near,
# Nearest to not: never, actually, still, they, always, herring, now, generally,
# Nearest to most: more, less, modernisation, many, some, among, detested, throughout,
# Nearest to these: several, many, some, those, certain, such, elaborately, instead,
# Nearest to by: through, without, when, jed, during, emanating, using, banco,
# Nearest to state: city, regrets, degeneracy, classifies, states, harvard, impedance, biopsy,
# Nearest to new: different, particular, salamander, bouillon, questionnaire, disco, sympathizers, arching,
# Nearest to for: while, when, during, without, amenable, if, blica, although,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in xrange(1, num_points+1)]
plot(two_d_embeddings, words)
